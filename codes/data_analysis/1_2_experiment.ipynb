# %%
import numpy as np
import matplotlib.pyplot as plt
#plt.rcParams['figure.dpi']= 300
import pandas as pd
import sys
import warnings
import glob

warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## L2 traffic

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

# Rate = 100Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l2/histogram_{100}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=100Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")
temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 100Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l2/hist_{100}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=100Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 100Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")






fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

# Rate = 1000Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l2/histogram_{1000}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=1000Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 1000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l2/hist_{1000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=1000Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 1000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))

print("-------------------------------------------------------------------")





fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

# Rate = 2000Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l2/histogram_{2000}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=2000Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 2000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l2/hist_{2000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=2000Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 2000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))



print("-------------------------------------------------------------------")


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

# Rate = 4000Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l2/histogram_{4000}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=4000Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 4000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l2/hist_{4000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=4000Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 4000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))



print("-------------------------------------------------------------------")



fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))


# Rate = 8000Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l2/histogram_{8000}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=8000Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 8000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l2/hist_{8000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=8000Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 8000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))
# Out:
# Mean delay for 100Mbps (40g-NIC): 276.3045707093962
# Mean delay for 100Mbps (10g-NIC): 2063.2155174940553
# -------------------------------------------------------------------
# Mean delay for 1000Mbps (40g-NIC): 276.25660612291523
# Mean delay for 1000Mbps (10g-NIC): 2059.9444990311704
# -------------------------------------------------------------------
# Mean delay for 2000Mbps (40g-NIC): 276.1975186405639
# Mean delay for 2000Mbps (10g-NIC): 2070.244538710548
# -------------------------------------------------------------------
# Mean delay for 4000Mbps (40g-NIC): 276.1524508066452
# Mean delay for 4000Mbps (10g-NIC): 2057.3001069085212
# -------------------------------------------------------------------
# Mean delay for 8000Mbps (40g-NIC): 276.2896142037111
# Mean delay for 8000Mbps (10g-NIC): 2047.7263669326967

# %% [markdown]
# ## L3 traffic

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

# Rate = 100Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l3/histogram_{100}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=100Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")
temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 100Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l3/hist_{100}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=100Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 100Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")






fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

# Rate = 1000Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l3/histogram_{1000}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=1000Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 1000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l3/hist_{1000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=1000Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 1000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))

print("-------------------------------------------------------------------")





fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

# Rate = 2000Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l3/histogram_{2000}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=2000Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 2000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l3/hist_{2000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=2000Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 2000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))



print("-------------------------------------------------------------------")


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

# Rate = 4000Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l3/histogram_{4000}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=4000Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 4000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l3/hist_{4000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=4000Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 4000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))



print("-------------------------------------------------------------------")



fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))


# Rate = 8000Mbps 
## 40g-NIC
df = pd.read_csv('/content/drive/MyDrive/Research/MinesVPN/Exp1/log/l3/histogram_{8000}.csv',names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax1.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=8000Mbps, 40G-NIC")
#ax1.set_xlim(200, 350)
ax1.set_xlabel("RTT of packets (ns)")

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 8000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/1-exp/10g-NIC/l3/hist_{8000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
df['mean_zero_delay'] = df['delay(ns)'] - df['delay(ns)'].mean()
ax2.bar(df['mean_zero_delay'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=8000Mbps, 10G-NIC")
#ax2.set_xlim(200, 350)

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 8000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))
# Out:
# Mean delay for 100Mbps (40g-NIC): 276.8104348813444
# Mean delay for 100Mbps (10g-NIC): 2146.397360121481
# -------------------------------------------------------------------
# Mean delay for 1000Mbps (40g-NIC): 276.8172821983138
# Mean delay for 1000Mbps (10g-NIC): 2150.4136347188664
# -------------------------------------------------------------------
# Mean delay for 2000Mbps (40g-NIC): 276.88281684702997
# Mean delay for 2000Mbps (10g-NIC): 2142.958926580387
# -------------------------------------------------------------------
# Mean delay for 4000Mbps (40g-NIC): 277.14649478974417
# Mean delay for 4000Mbps (10g-NIC): 2145.3813635514457
# -------------------------------------------------------------------
# Mean delay for 8000Mbps (40g-NIC): 277.2215358760943
# Mean delay for 8000Mbps (10g-NIC): 2146.5584915581003

# %% [markdown]
# ## Time between packets histogram

# %% [markdown]
# ### L2 traffic

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30,15))

# Rate = 100Mbps 
## 40g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/40g-NIC/l2/dist_{100}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax1.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=100Mbps, 40G-NIC")
ax1.set_xlim(0, 300)
ax1.set_xlabel('time between two packets (ns)')
temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 100Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/10g-NIC/l2/dist_{100}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax2.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=100Mbps, 10G-NIC")
ax2.set_xlim(0, 300)
ax2.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 100Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30,15))

# Rate = 1000Mbps 
## 40g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/40g-NIC/l2/dist_{1000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax1.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=1000Mbps, 40G-NIC")
ax1.set_xlim(0, 300)
ax1.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 100Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/10g-NIC/l2/dist_{1000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax2.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=1000Mbps, 10G-NIC")
ax2.set_xlim(0, 300)
ax2.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 1000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30,15))


# Rate = 2000Mbps 
## 40g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/40g-NIC/l2/dist_{2000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax1.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=2000Mbps, 40G-NIC")
ax1.set_xlim(0, 300)
ax1.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 2000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/10g-NIC/l2/dist_{2000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax2.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=2000Mbps, 10G-NIC")
ax2.set_xlim(0, 300)
ax2.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 2000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")



fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30,15))


# Rate = 4000Mbps 
## 40g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/40g-NIC/l2/dist_{4000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax1.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=4000Mbps, 40G-NIC")
ax1.set_xlim(0, 300)
ax1.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 4000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/10g-NIC/l2/dist_{4000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax2.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=4000Mbps, 10G-NIC")
ax2.set_xlim(0, 300)
ax2.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 4000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")
# Out:
# Mean delay for 100Mbps (40g-NIC): 2.1007533330924595
# Mean delay for 100Mbps (10g-NIC): 3.9285014955489728
# -------------------------------------------------------------------
# Mean delay for 100Mbps (40g-NIC): 1.6527821031571375
# Mean delay for 1000Mbps (10g-NIC): 3.3966257754821325
# -------------------------------------------------------------------
# Mean delay for 2000Mbps (40g-NIC): 1.8046272257217757
# Mean delay for 2000Mbps (10g-NIC): 3.9359545129882734
# -------------------------------------------------------------------
# Mean delay for 4000Mbps (40g-NIC): 3.8156746111490696
# Mean delay for 4000Mbps (10g-NIC): 3.482121939560757
# -------------------------------------------------------------------

# %% [markdown]
# ### L3 traffic

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30,15))

# Rate = 100Mbps 
## 40g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/40g-NIC/l3/dist_{100}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax1.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=100Mbps, 40G-NIC")
ax1.set_xlim(0, 300)
ax2.set_xlabel('time between two packets (ns)')
temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 100Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/10g-NIC/l3/dist_{100}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax2.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=100Mbps, 10G-NIC")
ax2.set_xlim(0, 300)
ax2.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 100Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30,15))

# Rate = 1000Mbps 
## 40g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/40g-NIC/l3/dist_{1000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax1.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=1000Mbps, 40G-NIC")
ax1.set_xlim(0, 300)
ax1.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 1000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/10g-NIC/l3/dist_{1000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax2.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=1000Mbps, 10G-NIC")
ax2.set_xlim(0, 300)
ax2.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 1000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30,15))


# Rate = 2000Mbps 
## 40g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/40g-NIC/l3/dist_{2000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax1.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=2000Mbps, 40G-NIC")
ax1.set_xlim(0, 300)
ax1.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 2000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/10g-NIC/l3/dist_{2000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax2.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=2000Mbps, 10G-NIC")
ax2.set_xlim(0, 300)
ax2.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 2000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")



fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30,15))


# Rate = 4000Mbps 
## 40g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/40g-NIC/l3/dist_{4000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax1.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax1.set_title("Rate=4000Mbps, 40G-NIC")
ax1.set_xlim(0, 300)
ax1.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 4000Mbps (40g-NIC): " + str(temp_values.sum()/temp_packets))

## 10g-NIC
df = pd.read_csv(glob.glob('/content/drive/MyDrive/Research/MinesVPN/data/2-exp/10g-NIC/l3/dist_{4000}Mbps_*.csv')[0],names=['delay(ns)', 'Num_Pkt'])
### Create bars
ax2.bar(df['delay(ns)'], np.log10(df['Num_Pkt']))
ax2.set_title("Rate=4000Mbps, 10G-NIC")
ax2.set_xlim(0, 300)
ax2.set_xlabel('time between two packets (ns)')

temp_values = df['delay(ns)'] * df['Num_Pkt']
temp_packets = df['Num_Pkt'].sum()
print("Mean delay for 4000Mbps (10g-NIC): " + str(temp_values.sum()/temp_packets))


print("-------------------------------------------------------------------")
# Out:
# Mean delay for 100Mbps (40g-NIC): 2.458347294235236
# Mean delay for 100Mbps (10g-NIC): 3.739055804014526
# -------------------------------------------------------------------
# Mean delay for 1000Mbps (40g-NIC): 1.2598241002026993
# Mean delay for 1000Mbps (10g-NIC): 3.44647362519273
# -------------------------------------------------------------------
# Mean delay for 2000Mbps (40g-NIC): 1.1557969574278397
# Mean delay for 2000Mbps (10g-NIC): 3.7275290738405493
# -------------------------------------------------------------------
# Mean delay for 4000Mbps (40g-NIC): 1.203618213719912
# Mean delay for 4000Mbps (10g-NIC): 3.729481827470442
# -------------------------------------------------------------------
