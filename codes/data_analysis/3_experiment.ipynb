# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/asabzi/data/3-exp/10G-NIC/l3/laten.txt", names= ['delay','tx','rx','block_1','block_2','block_3','duration'])
display(len(df))
df.sort_values(by=['tx'], inplace=True)
df_rtx_1 = df.iloc[:-1,[1,2]].reset_index()
df_rtx_2 = df.iloc[1:,[1,2]].reset_index()
df_diffs = df_rtx_2 - df_rtx_1 
df['rate'] = (1/df['duration']) * 128 * 8 /1e6
print(df['rate'].mean())
print(df['rate'].var())
display(df)
display(df_diffs)
plt.plot(df_diffs['tx'][:-100,])
# Out:
# 927
# 0.010250624839841842
# 3.918289928407349e-08
#      delay     tx     rx   block_1   block_2   block_3  duration      rate
# 325   2160  19145  21305  0.000037  0.000027  0.000011  0.099994  0.010241
# 520   2148  19171  21319  0.000038  0.000023  0.000011  0.099996  0.010240
# 625   2139  19187  21326  0.000040  0.000023  0.000011  0.099995  0.010241
# 529   2144  19190  21334  0.000039  0.000023  0.000011  0.099996  0.010240
# 454   2131  19193  21324  0.000037  0.000025  0.000011  0.099989  0.010241
# ..     ...    ...    ...       ...       ...       ...       ...       ...
# 102   2148  29987  32135  0.000278  0.000048  0.000025  0.099921  0.010248
# 0     2144  30511  32655  0.000131  0.000043  0.000035  0.100002  0.010240
# 233   2133  31468  33601  0.000042  0.000064  0.000014  0.099988  0.010241
# 13    2131  73395  75526  0.000382  0.000120  0.000020  0.099962  0.010244
# 37    2156  83567  85723  0.000048  0.000092  0.000059  0.099995  0.010241
#
# ...
